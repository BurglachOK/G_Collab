# %% [markdown]
# # ***Imports***

# %%
from sympy import diff, sqrt
from sympy.abc import x,y
from sympy.plotting import plot
from sympy import Rational
import seaborn as sns

# %% [markdown]
# # ***Завдання 1***

# %% [markdown]
# ![photo_2025-05-04_02-49-45.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **A**

# %%
exprA = ((x**3)/3) + ((x**2)/2) - 2*x
exprA
# Out:
# x**3/3 + x**2/2 - 2*x

# %%
difA = diff(exprA,x)
difA
# Out:
# x**2 + x - 2

# %%
resultA1 = difA.subs(x, 1)
resultA1
# Out:
# 0

# %%
resultA2 = difA.subs(x, -1/2)
resultA2
# Out:
# -2.25000000000000

# %% [markdown]
# **B**

# %%
exprB = sqrt((x**2) + 1)
exprB
# Out:
# sqrt(x**2 + 1)

# %%
difB = diff(exprB, x)
difB
# Out:
# x/sqrt(x**2 + 1)

# %%
resultB1 = difB.subs(x, 1)
resultB1
# Out:
# sqrt(2)/2

# %%
resultB2 = difB.subs(x, Rational(-1, 2))
resultB2
# Out:
# -sqrt(5)/5

# %% [markdown]
# **C**

# %%
exprC = 1 / sqrt((x**2) + 1)
exprC
# Out:
# 1/sqrt(x**2 + 1)

# %%
difC = diff(exprC, x)
difC
# Out:
# -x/(x**2 + 1)**(3/2)

# %%
resultC1 = difC.subs(x, 1)
resultC1
# Out:
# -sqrt(2)/4

# %%
resultC2 = difC.subs(x, Rational(-1, 2))
resultC2
# Out:
# 4*sqrt(5)/25

# %% [markdown]
# # Завдання ***2***

# %% [markdown]
# ![photo_2025-05-04_02-49-51.jpg](data:image/jpeg;base64,...)

# %%
p1 = plot(-3 * x**2 + 30 * x, show=False)
p2 = plot(-6 * x + 30, show=False)
p3 = plot(markers=[{"args": [[5], [75], "o"]}], show=False)
p1.extend(p2)
p1.extend(p3)
p1.show()
