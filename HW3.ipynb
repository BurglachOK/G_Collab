# %% [markdown]
# <a href="https://colab.research.google.com/github/BurglachOK/G_Collab/blob/main/HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Дано 4 точки: $M_0(0, 0, 0), M_1(1, \frac{1}{3}, 0), M_2(0, 2, \frac{1}{4}), M_3(\frac{1}{2}, \frac{1}{2}, 1)$.
#
# Також дано 3 вектори, які задають паралелепіпед із зазначеними точками:
# - $\overline{a}=\overline{M_0M_1}$
# - $\overline{b}=\overline{M_0M_2}$
# - $\overline{c}=\overline{M_0M_3}$
#
# Порахуй координати векторів через задані точки.
# Порахуй об'єм, площу повної поверхні паралелепіпеда та кути між ребрами паралелепіпеда, координати решти вершин паралелепіпеда.

# %% [markdown]
# $\overline{a} = M_1 =
# \left (\begin{array}{cc}
# 1\\
# \frac{1}{3}\\
# 0
# \end{array}\right)
# \\
# \overline{b} = M_2 = \left (\begin{array}{cc}
# 0\\
# 2\\
# \frac{1}{4}
# \end{array}\right)
# \\
# \overline{c} = M_3 = \left (\begin{array}{cc}
# \frac{1}{2}\\
# \frac{1}{2}\\
# 1
# \end{array}\right)
# $

# %% [markdown]
# $
# V ≈ 2.47\\
# S ≈ 10.503\\
# \angle(a, b) ≈ 71,71°\\
# \angle(a, c) ≈ 58,91°\\
# \angle(b, c) ≈ 59,58°\\
# M_4 = \left (\begin{array}{cc}
# \frac{1}{2}\\
# 2\frac{1}{2}\\
# 1\frac{1}{4}
# \end{array}\right)\\
# M_5 = \left (\begin{array}{cc}
# 1\\
# 2\frac{1}{3}\\
# \frac{1}{4}
# \end{array}\right)\\
# M_6 = \left (\begin{array}{cc}
# 1\frac{1}{2}\\
# 2\frac{5}{6}\\
# 1\frac{1}{4}
# \end{array}\right)\\
# M_7 = \left (\begin{array}{cc}
# 1\frac{1}{2}\\
# \frac{5}{6}\\
# 1
# \end{array}\right)\\
# $

# %% [markdown]
# # ***Рішення***

# %% [markdown]
# ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # ***Фото, оригінал, не обрізані***

# %% [markdown]
# ![1.orig.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![2.orig.jpg](data:image/jpeg;base64,...)
